# %% [markdown]
# <a href="https://colab.research.google.com/github/GUDDUemsec/SEMATIC-SEARCH/blob/main/Semantic_Search_with_FAISS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 19.1 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 51.9 MB/s
# ...
#      |████████████████████████████████| 182 kB 53.5 MB/s
# ...

# %%
from transformers import AutoTokenizer, TFAutoModel
import pandas as pd
import numpy as nv

# %%
file_data=pd.read_csv('/content/BBC_newsData.csv')
file_data
# Out:
#                                                Titles    Date&Time  \
# 0         Five-day strike by Greene King workers ends  0:45 10 Dec
# 1     Bank rules in biggest shake-up in over 30 years  21:19 9 Dec
# 2   Royal Mail workers begin wave of Christmas str...  21:04 9 Dec
# 3   Penguin boss resigns after US blocks takeover ...  20:41 9 Dec
# 4     Orkney Christmas businesses hit by mail strikes  20:00 9 Dec
# 5         Santander fined £108m by financial watchdog  17:00 9 Dec
# 6                  Is Labour really back in business?   1:45 9 Dec
# 7   Council tracks people's phones to monitor foot...  23:14 8 Dec
# 8   'We haven't had a single penny from the Post O...  20:59 8 Dec
# 9               Striking use of Holyrood’s tax powers  19:00 8 Dec
# 10  What happens if I can't afford to pay my mortg...  17:08 8 Dec
# 11      What are my rights if my flight is cancelled?  16:57 8 Dec
# 12                 What is happening to house prices?  16:39 8 Dec
# ...

# %%
model_ckpt = "sentence-transformers/multi-qa-mpnet-base-dot-v1"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = TFAutoModel.from_pretrained(model_ckpt, from_pt=True)
# Out:
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFMPNetModel: ['embeddings.position_ids']
# - This IS expected if you are initializing TFMPNetModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFMPNetModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFMPNetModel were initialized from the PyTorch model.
# ...

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 451 kB 21.4 MB/s
# ...
#      |████████████████████████████████| 212 kB 45.4 MB/s
# ...
#      |████████████████████████████████| 132 kB 49.6 MB/s
# ...
#      |████████████████████████████████| 127 kB 42.5 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# !pip install faiss-cpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 17.0 MB 284 kB/s
# ...

# %%
from datasets import Dataset

file_dataset = Dataset.from_pandas(file_data)
file_dataset
# Out:
# Dataset({
#     features: ['Titles', 'Date&Time', 'Images_URL', 'Article_links', 'Article_conetent'],
#     num_rows: 20
# })

# %%
def concatenate_text(examples):
    return {
        "text": examples["Titles"]
        }


file_dataset = file_dataset.map(concatenate_text)
file_dataset
# Out:
#   0%|          | 0/20 [00:00<?, ?ex/s]
# Dataset({
#     features: ['Titles', 'Date&Time', 'Images_URL', 'Article_links', 'Article_conetent', 'text'],
#     num_rows: 20
# })

# %%
def cls_pooling(model_output):
    return model_output.last_hidden_state[:, 0]

# %%
def get_embeddings(text_list):
    encoded_input = tokenizer(
        text_list, padding=True, truncation=True, return_tensors="tf"
    )
    encoded_input = {k: v for k, v in encoded_input.items()}
    model_output = model(**encoded_input)
    return cls_pooling(model_output)

# %%
embedding = get_embeddings(file_dataset["text"][0])
embedding.shape
# Out:
# TensorShape([1, 768])

# %%
embeddings_dataset = file_dataset.map(
    lambda x: {"embeddings": get_embeddings(x["text"]).numpy()[0]}
)
# Out:
# WARNING:absl:Found untraced functions such as encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses, pooler_layer_call_fn, pooler_layer_call_and_return_conditional_losses, embeddings_layer_call_fn while saving (showing 5 of 396). These functions will not be directly callable after loading.
#   0%|          | 0/20 [00:00<?, ?ex/s]

# %%
embeddings_dataset.add_faiss_index(column='embeddings')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset({
#     features: ['Titles', 'Date&Time', 'Images_URL', 'Article_links', 'Article_conetent', 'text', 'embeddings'],
#     num_rows: 20
# })

# %%
question = input("Search:")
question_embedding = get_embeddings([question]).numpy()
question_embedding.shape
question_embedding
# Out:
# Search:First King Charles 50p coins enter circulation
# array([[-1.98525697e-01, -4.86938238e-01, -1.69099465e-01,
#          1.93978682e-01, -1.77072417e-02,  5.28325140e-02,
#          2.51864821e-01,  4.28069681e-02, -2.77223289e-01,
#          4.01232243e-01,  2.43995294e-01,  3.19818586e-01,
#          1.26359776e-01,  3.59872952e-02,  9.25114751e-03,
#          5.51118255e-02,  1.49915904e-01,  3.37846518e-01,
#         -1.02996185e-01, -3.38467434e-02, -2.33957857e-01,
#          1.60828114e-01, -3.01441669e-01,  1.90796666e-02,
#         -4.01268601e-02,  1.23559788e-01, -7.59252757e-02,
#          1.72957450e-01, -4.16908205e-01, -2.44597256e-01,
#          1.26068801e-01,  2.09801614e-01, -6.38155565e-02,
#          2.19304949e-01, -1.07490130e-04, -2.55732387e-01,
#          1.79153964e-01,  2.02973694e-01, -1.80710033e-01,
#          1.06775016e-01, -2.54600734e-01, -1.78157926e-01,
#         -5.75619936e-03, -6.85068592e-02, -2.52181500e-01,
# ...

# %%
scores, samples = embeddings_dataset.get_nearest_examples(
    "embeddings", question_embedding, k=5
)

# %%
import pandas as pd

samples_df = pd.DataFrame.from_dict(samples)
samples_df["scores"] = scores
samples_df.sort_values("scores", ascending=False, inplace=True)

# %%
for _, data in samples_df.iterrows():
    print("~" * 200)
    print(f"Titles: {data.text}\nArticle conetent: {data.Article_conetent}\nArticle links: {data.Article_links}")
    print("~" * 200)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Titles: Is Labour really back in business?
# ...
